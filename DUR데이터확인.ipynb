# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("data/한국의약품안전관리원_효능군중복주의약물_20230701.csv", encoding='cp949')
df_1.head(2)
# Out:
#      효능군     그룹구분      일반명코드       일반명 효능군중복점검코드       약품코드  \
# 0  당뇨병용제  Group 3  100601ATB  acarbose  396C0001  652100060
# 1  당뇨병용제  Group 3  100602ATB  acarbose  396C0001  652100050
#
#                              품목명    업체명  급여        공고일자      공고번호
# 0  글루코바이정100밀리그람(아카보즈)_(0.1g/1정)  (주)한독  급여  2020-09-24  20200423
# 1   글루코바이정50밀리그람(아카보즈)_(50mg/1정)  (주)한독  급여  2020-09-24  20200423

# %%
df_2 = pd.read_csv("data/한국의약품안전관리원_한국의약품안전관리원_임부금기약물_20230705.csv", encoding='cp949')
df_2.head(2)
# Out:
#                        성분명       성분코드       제품코드  \
# 0             Molnupiravir  707001ACS  655502130
# 1  alfuzosin hydrochloride  104803ATR   57000460
#
#                                 제품명        업체명        고시일자      고시번호  급여 금기등급  \
# 0        라게브리오캡슐(몰누피라비르)_(0.2g/1캡슐)  한국엠에스디(주)  2022-03-23  20200130  급여    1
# 1  알푸케어서방정10밀리그램(알푸조신염산염)_(10mg/1정)    (주)더유제약  2019-05-22  20160155  급여    2
#
#                            상세정보
# 0  임부 투여금기, 동물실험에서 간독성의 증거 나타남
# 1               임부에 대한 안전성 미확립.

# %%
df_3 = pd.read_csv("data/한국의약품안전관리원_투여기간주의약물_20230701.csv", encoding='cp949')
df_3.head(2)
# Out:
#         약품코드                                                약품명      일반명코드  \
# 0  652100640                   스틸녹스정10밀리그램(졸피뎀타르타르산염)_(10mg/1정)  250501ATB
# 1  649802851  케토신주사(케토롤락트로메타민염)(수출명:뉴케토신주사,NEWKETOCININJ)_(3...  180033BIJ
#
#                       일반명  최대투여기간일수        공고일자      공고번호  급여   비고    주성분함량
# 0                zolpidem        28  2017-02-16  20170079  급여  NaN     10mg
# 1  ketorolac tromethamine         2  2017-02-16  20170079  급여  NaN  30mg/mL

# %%
df_4 = pd.read_csv("data/한국의약품안전관리원_용량주의약물_20230701.csv", encoding='cp949')
df_4.head(2)
# Out:
#         약품코드                        약품명      일반명코드  \
# 0  625200290               로사탄플러스정_(1정)  262500ATB
# 1  645906290  동광로수바스타틴칼슘정5mg_(5.2mg/1정)  454003ATB
#
#           일반명(복합제의 경우 1성분만 표시됨)                      1일 최대투여량  1일최대 투여기준량  \
# 0  Losartan/Hydrochlorothiazide  로사르탄칼륨 100mg/히드로클로로티아지드 25mg       100.0
# 1                  Rosuvastatin                   로수바스타틴 20mg        20.0
#
#    점검기준 성분함량 (총함량)  급여        공고일자      공고번호 상세내용
# 0             50.0  급여  2021-12-16  20210599  NaN
# 1              5.0  급여  2021-12-16  20210599  NaN

# %%
df_6 = pd.read_csv("data/한국의약품안전관리원_병용금기약물_20230705.csv", encoding='cp949')
df_6.head(2)
# Out:
# C:\Users\1qlqj\AppData\Local\Temp\ipykernel_29800\3002519896.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_6 = pd.read_csv("data/한국의약품안전관리원_병용금기약물_20230705.csv", encoding='cp949')
#           성분명A      성분코드A      제품코드A                      제품명A     업소명A 구분A  \
# 0  aceclofenac  100901ACH  648101510  에이서캡슐(아세클로페낙)_(0.1g/1캡슐)  경동제약(주)  급여
# 1  aceclofenac  100901ACH  648101510  에이서캡슐(아세클로페낙)_(0.1g/1캡슐)  경동제약(주)  급여
#
#                      성분명B      성분코드B      제품코드B                         제품명B  \
# 0  ketorolac tromethamine  180001ATB  653400910   케토라신정(케토롤락트로메타민)_(10mg/1정)
# 1  ketorolac tromethamine  180033BIJ   59000681  케롤락주(케토롤락트로메타민염)_(30mg/1mL)
#
#          업소명B 구분B      고시번호       고시적용일           금기사유   비고
# 0     동국제약(주)  급여  20050017  2005-03-09  중증의 위장관계 이상반응  NaN
# 1  주식회사케이에스제약  급여  20050017  2005-03-09  중증의 위장관계 이상반응  NaN

# %%
df_7 = pd.read_csv("data/한국의약품안전관리원_노인주의약물_20230701.csv", encoding='cp949')
df_7.head(2)
# Out:
#                                    성분명       성분코드       제품코드  \
# 0  quetiapine fumarate (as quetiapine)  378610ATB  645306620
# 1  quetiapine fumarate (as quetiapine)  378610ATB  651904730
#
#                                      제품명      업소명        공고일자      공고번호  급여  \
# 0  카세핀정12.5밀리그램(쿠에티아핀푸마르산염)_(14.39mg/1정)  한림제약(주)  2021-07-15  20210248  급여
# 1  큐로켈정12.5밀리그램(쿠에티아핀푸마르산염)_(14.39mg/1정)  명인제약(주)  2021-07-15  20210248  급여
#
#                                               약품상세정보
# 0  다른 항정신병약과 같이 이 약을 장기간 투여 후 지연성운동이상 일으킬 위험이 있음....
# 1  다른 항정신병약과 같이 이 약을 장기간 투여 후 지연성운동이상 일으킬 위험이 있음....

# %%
df_8 = pd.read_csv("data/건강보험심사평가원_임산부 금기 의약품목록_20220501.csv", encoding='cp949')
df_8.head(2)
# Out:
#      구분                                           성분명       성분코드         제품코드  \
# 0  급여품목  Chenodeoxycholic acid + Ursodeoxycholic acid  100301ACH  649804410.0
# 1  급여품목                                   acamprosate  100501ATE  651904740.0
#
#                                             제품명      업체명        고시일자  \
# 0  씨앤유캡슐(케노데속시콜산-우르소데속시콜산삼수화물마그네슘염)_(0.25g/1캡슐)  명문제약(주)  2020-12-28
# 1        명인아캄프로세이트정333mg(아캄프로세이트칼슘)_(0.333g/1정)  명인제약(주)  2016-12-30
#
#          고시번호 금기등급                          상세정보
# 0  20200130.0    1  임부 투여금기, 동물실험에서 간독성의 증거 나타남
# 1  20160155.0    2               임부에 대한 안전성 미확립.

# %%
df_9 = pd.read_csv("data/건강보험심사평가원_연령별 금기 의약품목록_20230501.csv", encoding='cp949')
df_9.head(2)
# Out:
#      구분          성분명       성분코드       제품코드  \
# 0  급여품목  acamprosate  100501ATE  651904740
# 1  급여품목  acamprosate  100501ATE  657201040
#
#                                       제품명      업체명  특정연령 특정연령단위-1 특정연령단위-2  \
# 0  명인아캄프로세이트정333mg(아캄프로세이트칼슘)_(0.333g/1정)  명인제약(주)    65    세 (3)   이상 (4)
# 1       환인아캄프로세이트정(아캄프로세이트칼슘)_(0.333g/1정)  환인제약(주)    65    세 (3)   이상 (4)
#
#        고시번호        고시일자                                               상세정보
# 0  20190041  2019-05-22  65세 이상에서 안전성 및 유효성 미확립. 연령이 높아질수록 신장기능이 저하되어 이...
# 1  20190041  2019-05-22  65세 이상에서 안전성 및 유효성 미확립. 연령이 높아질수록 신장기능이 저하되어 이...

# %%
df_11 = pd.read_csv("data/의약품낱알식별정보.csv")
df_11.head(2).T
# Out:
#                                                                0  \
# 품목일련번호                                                 200808876
# 품목명                                      가스디알정50밀리그램(디메크로틴산마그네슘)
# 업체일련번호                                                  19540006
# 업체명                                                      일동제약(주)
# 성상                                                  녹색의 원형 필름코팅정
# 큰제품이미지         https://nedrug.mfds.go.kr/pbp/cmn/itemImageDow...
# 표시(앞)                                                        IDG
# 표시(뒤)                                                        NaN
# 의약품모양                                                         원형
# 색깔(앞)                                                         연두
# 색깔(뒤)                                                        NaN
# 분할선(앞)                                                       NaN
# 분할선(뒤)                                                       NaN
# ...

# %%
df_12 = pd.read_csv("data/의약품개요정보.csv")
df_12.head(2).T
# Out:
#                                                         0  \
# 업체명                                          ('동화약품(주)',)
# 제품명                                              ('활명수',)
# 품목기준코드                                     ('195700020',)
# 효능      ('이 약은 식욕감퇴(식욕부진), 위부팽만감, 소화불량, 과식, 체함, 구역, 구토...
# 사용법     ('만 15세 이상 및 성인은 1회 1병(75 mL), 만 11세이상~만 15세미만...
# 경고                                                    NaN
# 주의사항    ('만 3개월 미만의 젖먹이는 이 약을 복용하지 마십시오.\n\n이 약을 복용하기 ...
# 상호작용                                                  NaN
# 부작용                                               (None,)
# 보관법     ('습기와 빛을 피해 실온에서 보관하십시오.\n\n어린이의 손이 닿지 않는 곳에 보...
# 공개일자                             ('2021-01-29 00:00:00',)
# 수정일자                                      ('2024-01-11',)
# 낱알이미지                                             (None,)
#
#                                                         1
# 업체명                                          ('신신제약(주)',)
# ...

# %%
df_12.sort_values(by='품목기준코드', ascending=False)
# Out:
#                    업체명                                         제품명  \
# 4658      ('부광약품(주)',)                                ('뱅드롱에스시럽',)
# 4657      ('영일제약(주)',)                                   ('아이렌정',)
# 4656  ('성이바이오제약주식회사',)                            ('조인트콘친600골드정',)
# 4655      ('(주)바이넥스',)      ('누네프레쉬점안액1.0%(카르복시메틸셀룰로오스나트륨)(1회용)',)
# 4654      ('(주)유유제약',)                  ('펙소지엔정60밀리그램(펙소페나딘염산염)',)
# ...                ...                                         ...
# 8         ('(주)유한양행',)                     ('페니라민정(클로르페니라민말레산염)',)
# 7         ('정우신약(주)',)                                     ('자모',)
# 2         ('삼진제약(주)',)                                   ('아네모정',)
# 1         ('신신제약(주)',)  ('신신티눈고(살리실산반창고)(수출명:SINSINCORNPLASTER)',)
# 0         ('동화약품(주)',)                                    ('활명수',)
#
#               품목기준코드                                                 효능  \
# 4658  ('202302217',)     ('이 약은 멀미에 의한 어지러움·구토·두통의 예방 및 완화에 사용합니다.\n',)
# ...

# %%
print(df_1.info())
print(df_2.info())
print(df_3.info())
print(df_4.info())
print(df_6.info())
print(df_7.info())
print(df_8.info())
print(df_9.info())
print(df_11.info())
print(df_12.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15329 entries, 0 to 15328
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   효능군        15329 non-null  object
#  1   그룹구분       15329 non-null  object
#  2   일반명코드      15329 non-null  object
#  3   일반명        15329 non-null  object
#  4   효능군중복점검코드  15329 non-null  object
#  5   약품코드       15329 non-null  int64
#  6   품목명        15329 non-null  object
#  7   업체명        15329 non-null  object
#  8   급여         15329 non-null  object
#  9   공고일자       15329 non-null  object
#  10  공고번호       15329 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 1.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19318 entries, 0 to 19317
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   성분명     19318 non-null  object
#  1   성분코드    19318 non-null  object
# ...

# %%
df_11[df_11['품목명'] == '케토신주사']
