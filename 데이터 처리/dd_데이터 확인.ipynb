# %%
import pandas as pd

# %%
df_A = pd.read_csv("data/ddinter_downloads_code_A.csv")

# %%
df_A.head()
# Out:
#    DDInterID_A              Drug_A  DDInterID_B        Drug_B     Level
# 0  DDInter1263          Naltrexone     DDInter1      Abacavir  Moderate
# 1     DDInter1            Abacavir  DDInter1348      Orlistat  Moderate
# 2    DDInter58  Aluminum hydroxide   DDInter582  Dolutegravir     Major
# 3   DDInter112          Aprepitant   DDInter582  Dolutegravir     Minor
# 4   DDInter138         Attapulgite   DDInter582  Dolutegravir     Major

# %%
df_B = pd.read_csv("data/ddinter_downloads_code_B.csv")

# %%
df_B.head()
# Out:
#   DDInterID_A        Drug_A  DDInterID_B              Drug_B  Level
# 0  DDInter975          Iron   DDInter582        Dolutegravir  Major
# 1  DDInter582  Dolutegravir   DDInter725    Ferrous fumarate  Major
# 2  DDInter582  Dolutegravir   DDInter726   Ferrous gluconate  Major
# 3  DDInter582  Dolutegravir  DDInter1114  Magnesium chloride  Major
# 4  DDInter582  Dolutegravir  DDInter1115   Magnesium citrate  Major

# %%
df_D = pd.read_csv("data/ddinter_downloads_code_D.csv")

# %%
df_D.head()
# Out:
#   DDInterID_A           Drug_A DDInterID_B             Drug_B  Level
# 0  DDInter690          Ethanol    DDInter1           Abacavir  Minor
# 1  DDInter582     Dolutegravir  DDInter276  Calcium gluconate  Major
# 2  DDInter351  Chloramphenicol  DDInter582       Dolutegravir  Minor
# 3  DDInter416     Clotrimazole  DDInter582       Dolutegravir  Minor
# 4  DDInter513    Dexamethasone  DDInter582       Dolutegravir  Minor

# %%
df_H = pd.read_csv("data/ddinter_downloads_code_H.csv")

# %%
df_H.head()
# Out:
#    DDInterID_A         Drug_A  DDInterID_B        Drug_B     Level
# 0   DDInter513  Dexamethasone   DDInter582  Dolutegravir     Minor
# 1   DDInter582   Dolutegravir   DDInter625      Elagolix     Minor
# 2   DDInter582   Dolutegravir  DDInter1700      Somatrem     Minor
# 3  DDInter1699   Somatotropin   DDInter582  Dolutegravir     Minor
# 4   DDInter195  Betamethasone  DDInter1961    Zidovudine  Moderate

# %%
df_L = pd.read_csv("data/ddinter_downloads_code_L.csv")

# %%
df_L.head()
# Out:
#   DDInterID_A                         Drug_A DDInterID_B               Drug_B  \
# 0  DDInter127  Asparaginase Escherichia coli    DDInter1             Abacavir
# 1    DDInter1                       Abacavir  DDInter228  Brentuximab vedotin
# 2    DDInter1                       Abacavir  DDInter262         Cabozantinib
# 3  DDInter392                     Cladribine    DDInter1             Abacavir
# 4  DDInter405                    Clofarabine    DDInter1             Abacavir
#
#       Level
# 0  Moderate
# 1  Moderate
# 2  Moderate
# 3  Moderate
# 4  Moderate

# %%
df_P = pd.read_csv("data/ddinter_downloads_code_P.csv")

# %%
df_P.head()
# Out:
#    DDInterID_A      Drug_A  DDInterID_B              Drug_B     Level
# 0   DDInter576  Disulfiram     DDInter1            Abacavir     Minor
# 1  DDInter1961  Zidovudine   DDInter134          Atovaquone     Minor
# 2  DDInter1961  Zidovudine   DDInter359         Chloroquine  Moderate
# 3  DDInter1961  Zidovudine   DDInter893  Hydroxychloroquine  Moderate
# 4  DDInter1961  Zidovudine  DDInter1044          Levamisole  Moderate

# %%
df_R = pd.read_csv("data/ddinter_downloads_code_R.csv")

# %%
df_R.head()
# Out:
#    DDInterID_A         Drug_A  DDInterID_B        Drug_B     Level
# 0   DDInter513  Dexamethasone   DDInter582  Dolutegravir     Minor
# 1   DDInter997      Ivacaftor   DDInter582  Dolutegravir     Minor
# 2  DDInter1019     Lamivudine  DDInter1123      Mannitol  Moderate
# 3   DDInter195  Betamethasone  DDInter1961    Zidovudine  Moderate
# 4  DDInter1961     Zidovudine   DDInter246    Budesonide  Moderate

# %%
df_V = pd.read_csv("data/ddinter_downloads_code_V.csv")

# %%
df_V.head()
# Out:
#    DDInterID_A           Drug_A DDInterID_B        Drug_B     Level
# 0     DDInter1         Abacavir  DDInter424    Cobicistat  Moderate
# 1   DDInter690          Ethanol    DDInter1      Abacavir     Minor
# 2   DDInter270  Calcium acetate  DDInter582  Dolutegravir     Major
# 3  DDInter1019       Lamivudine  DDInter424    Cobicistat  Moderate
# 4   DDInter488      Deferasirox  DDInter582  Dolutegravir     Minor
